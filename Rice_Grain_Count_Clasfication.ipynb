# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\broken_grain_1.jpg') ## loading the images
img2 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\broken_grain_2.jpg')
img3 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\broken_grain_2.jpg')
img4 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\full_grain_1.jpg')
img5 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\full_grain_2.jpg')
img6 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\full_grain_4.jpg')
img7 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\full_grain_5.jpg')
img8 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\full_grain_6.jpg')
img9 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\full_grain_7.jpg')
img10 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\mixed_grain_1.jpg')
img11 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\mixed_grain_2.jpg')
img12 = cv2. imread(r'C:\Users\Junaid\Pictures\rice_images\mixed_grain_3.jpg')

# %%
img1
img2
img3
img4
img5
img6
img7
img8
img9
img10

# %%
#making the image to Gray for analysation
gray1=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

plt.imshow(gray1,cmap='gray')

gray2=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

plt.imshow(gray2,cmap='gray')


gray3=cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)

plt.imshow(gray3,cmap='gray')

gray4=cv2.cvtColor(img4,cv2.COLOR_BGR2GRAY)

plt.imshow(gray4,cmap='gray')

gray5=cv2.cvtColor(img5,cv2.COLOR_BGR2GRAY)

plt.imshow(gray5,cmap='gray')


gray6=cv2.cvtColor(img6,cv2.COLOR_BGR2GRAY)

plt.imshow(gray6,cmap='gray')


gray7=cv2.cvtColor(img7,cv2.COLOR_BGR2GRAY)

plt.imshow(gray7,cmap='gray')


gray8=cv2.cvtColor(img8,cv2.COLOR_BGR2GRAY)

plt.imshow(gray8,cmap='gray')


gray9=cv2.cvtColor(img9,cv2.COLOR_BGR2GRAY)

plt.imshow(gray9,cmap='gray')


gray10=cv2.cvtColor(img10,cv2.COLOR_BGR2GRAY)

plt.imshow(gray10,cmap='gray')

# %%
# making the image to get blurred  to avoiad not to capture noise only to capture edges
blur=cv2.GaussianBlur(gray,(11,11),0)
plt.imshow(gray,cmap='gray')

# %%
# algorithm to detect and calcluate the edges

#The Canny edge detector is an edge detection operator that 
#uses a multi-stage algorithm to detect a wide range of edges in images


canny=cv2.Canny(blur,30,150,3)
plt.imshow(canny,cmap='gray')

# %%
# now we got edges and but we need to connect these edges for calculatons

#To apply a morphological filter to images in Python using OpenCV, use the cv2 dilate() method. The dilate() method takes two inputs in which one is our input image; the second is called the structuring element or kernel, 
#which decides the nature of the operation.

dilated=cv2.dilate(canny,(1,1), iterations=2)
plt.imshow(dilated,cmap='gray')

# %%
#now we are calculating the rice grains

#In OpenCV, finding the contour in the binary image is
#the same as finding white object from a black background. 
#OpenCV provides findContours(), which is used to find the 
#contour in the binary image

(cnt,hairarchy)=cv2.findContours(dilated.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb,cnt,-1,(0,255,0),2)

plt.imshow(rgb)

# %%
#  counting the no of rice grains in an image
print("rice in the image are",len(cnt))
# Out:
# rice in the image are 542

# %%
#now by taking the MIxed Grain Rice we are going to calculate the rice grains in an image
# making the image to get blurred  to avoiad not to capture noise only to capture edges
blur1=cv2.GaussianBlur(gray10,(11,11),0)
plt.imshow(gray10,cmap='gray')

# %%
# algorithm to detect and calcluate the edges

#The Canny edge detector is an edge detection operator that 
#uses a multi-stage algorithm to detect a wide range of edges in images

canny1=cv2.Canny(blur1,30,150,3)
plt.imshow(canny1,cmap='gray')

# %%
# now we got edges and but we need to connect these edges for calculatons
dilated1=cv2.dilate(canny1,(1,1), iterations=2)
plt.imshow(dilated1,cmap='gray')

# %%
#now we are calculating the rice grains
(cnt1,hairarchy)=cv2.findContours(dilated1.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
rgb=cv2.cvtColor(img10,cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb,cnt1,-1,(0,255,0),2)

plt.imshow(rgb)

# %%
#  counting the no of rice grains in an image
print("rice in the image are",len(cnt1))
# Out:
# rice in the image are 353
